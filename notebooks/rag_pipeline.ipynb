# %% [markdown]
# <a href="https://colab.research.google.com/github/marcelalozano27-ship-it/bsan6200-assignment5/blob/main/rag_pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 5 — Option B: Job Fit Analyzer
# ## BSAN 6200: Text Mining & Social Media Analytics — Spring 2026
#
# **Student Name:** Marcela Lozano
# **Option:** B — Job Fit Analyzer
# **API Path:** [Paid ]
#
# ---
#
# ### Table of Contents
# 1. [Setup and Imports](#1-setup)
# 2. [Load Job Descriptions and Resume](#2-loading)
# 3. [Text Chunking](#3-chunking)
# 4. [Embedding and Vector Store](#4-embedding)
# 5. [Analysis Prompts and Chain](#5-analysis)
# 6. [Zero-shot vs. Few-shot Comparison](#6-comparison)
# 7. [Evaluation](#7-evaluation)
#
# > **Reminder:** The Streamlit app is a separate file (`streamlit_app.py`). This notebook builds and tests the analysis pipeline.
# > See the Option B Implementation Guide for detailed step requirements.

# %% [markdown]
# ---
# <a id="1-setup"></a>
# ## 1. Setup and Imports
#
# Install required packages and load your API key from a `.env` file.
# **Do NOT hardcode API keys in this notebook.**
#
# Suggested packages: `langchain`, `langchain-openai` or `langchain-community`, `chromadb` or `faiss-cpu`, `pypdf`, `python-dotenv`, `pandas`, `sentence-transformers` (free path)

# %%
# ── Install packages ──
# !pip install -q chromadb sentence-transformers huggingface-hub python-dotenv

import os
import re
import pandas as pd
import requests
import numpy as np
from dotenv import load_dotenv
from sentence_transformers import SentenceTransformer
load_dotenv()


print("Imports working")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.3/23.3 MB 82.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 24.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 82.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 101.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.1/72.1 kB 6.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.2/180.2 kB 16.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.0/69.0 kB 7.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.6/231.6 kB 18.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 6.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 5.4 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opentelemetry-exporter-otlp-proto-http 1.38.0 requires opentelemetry-exporter-otlp-proto-common==1.38.0, but you have opentelemetry-exporter-otlp-proto-common 1.41.1 which is incompatible.
# opentelemetry-exporter-otlp-proto-http 1.38.0 requires opentelemetry-proto==1.38.0, but you have opentelemetry-proto 1.41.1 which is incompatible.
# opentelemetry-exporter-otlp-proto-http 1.38.0 requires opentelemetry-sdk~=1.38.0, but you have opentelemetry-sdk 1.41.1 which is incompatible.
# opentelemetry-exporter-gcp-logging 1.11.0a0 requires opentelemetry-sdk<1.39.0,>=1.35.0, but you have opentelemetry-sdk 1.41.1 which is incompatible.
# google-adk 1.29.0 requires opentelemetry-api<1.39.0,>=1.36.0, but you have opentelemetry-api 1.41.1 which is incompatible.
# google-adk 1.29.0 requires opentelemetry-sdk<1.39.0,>=1.36.0, but you have opentelemetry-sdk 1.41.1 which is incompatible.
# Imports working

# %% [markdown]
# ---
# <a id="2-loading"></a>
# ## 2. Load Job Descriptions and Resume
#
# **Required:**
# - 10+ JD files in `data/job_descriptions/` (each as a separate .txt or .pdf)
# - Your resume in `data/resume/`
# - A metadata file `data/jd_metadata.csv` with columns: filename, company, title, source_url, date_collected
#
# Print: number of JDs loaded, number of resume docs, and preview content from each.

# %%
# ── Load JD metadata ──
jd_metadata = pd.read_csv(
    "https://raw.githubusercontent.com/marcelalozano27-ship-it/bsan6200-assignment5/main/data/jd_metadata.csv"
)

print(jd_metadata)
# Out:
#                                              filename                Company  \
# 0                 jd_LAClippers_data_analyst_lead.txt            LA Clippers
# 1         jd_alo_production_supplyplanning_intern.txt                    ALO
# 2                jd_axs_associate_product_manager.txt                    AXS
# 3          jd_ephemeris_financial_strategy_intern.txt             Ephemeris
# 4                       jd_fedex_analytics_intern.txt                 Fedex
# 5           jd_revolve_data_analyst_merchandising.txt                Revolve
# 6       jd_roku_content_analytics_insights_intern.txt                   Roku
# 7       jd_skechers_strategic_partnerships_intern.txt               Skechers
# 8   jd_sony_insights_research_analytics_summerinte...                   Sony
# 9      jd_tiktok_strategic_partner_manager_intern.txt                 TikTok
# 10         jd_tinder_corporate_rotational_analyst.txt                 Tinder
# 11  jd_universalmusicgroup_Brand_label_operations.txt  Universal Music Group
# 12           jd_vast_business_supply_chain_intern.txt                   Vast
#
#                                     title  \
# 0                       Data Analyst Lead
# 1     Production & Supply Planning Intern
# 2               Associate Product Manager
# 3               Financial Strategy Intern
# 4                  Fedex Analytics Intern
# 5              Data Analyst Merchandising
# 6   Content Analytics and Insights Intern
# 7           Strategic Partnerships Intern
# 8       Research Analytics Summer Intern
# 9        Strategic Partner Manager Intern
# 10           Corporate Rotational Analyst
# 11                 Brand Label Operations
# 12           Business Supply Chain Intern
#
#                                            source_url date_collected
# 0   https://www.nba.com/clippers/company/careers/o...      4/27/2026
# 1               https://www.aloyoga.com/pages/careers      4/26/2026
# 2   https://job-boards.greenhouse.io/axs/jobs/8471...      4/27/2026
# 3   https://ats.rippling.com/ephemeris-net/jobs/95...      4/24/2026
# 4   https://careers.fedex.com/career-areas/student...      4/24/2026
# 5   https://workforcenow.adp.com/mascsr/default/md...      4/27/2026
# 6              https://www.weareroku.com/early-career      4/28/2026
# 7   https://careers.skechers.com/us/en/job/JR12615...      4/26/2026
# 8   https://www.sonypicturesjobs.com/job/-/-/22978...      4/27/2026
# 9   https://lifeattiktok.com/search/75441503667424...      4/24/2026
# 10  https://www.lifeattinder.com/positions/4dd0174...      4/27/2026
# 11            https://www.universalmusic.com/careers/      4/27/2026
# 12                 https://www.vastspace.com/careers?      4/28/2026

# %%
# ── Load JD documents and resume ──
from langchain_core.documents import Document
import requests

jd_documents = []

base_url = "https://raw.githubusercontent.com/marcelalozano27-ship-it/bsan6200-assignment5/main/data/job_descriptions/"

for _, row in jd_metadata.iterrows():
    filename = row["filename"]
    url = base_url + filename

    text = requests.get(url).text

    doc = Document(
        page_content=text,
        metadata={
            "filename": filename,
            "company": row.get("Company", ""),
            "title": row.get("title", ""),
            "source_url": row.get("source_url", ""),
            "date_collected": row.get("date_collected", ""),
            "doc_type": "job_description"
        }
    )

    jd_documents.append(doc)

print("Loaded job descriptions:", len(jd_documents))
print(jd_documents[0].metadata)
print(jd_documents[0].page_content[:500])
# Out:
# Loaded job descriptions: 13
# {'filename': 'jd_LAClippers_data_analyst_lead.txt', 'company': 'LA Clippers', 'title': 'Data Analyst Lead', 'source_url': 'https://www.nba.com/clippers/company/careers/openpositionlaclippers?gh_jid=4651394006&gh_src=9f5ba8c96us', 'date_collected': '4/27/2026', 'doc_type': 'job_description'}
#
# The LA Clippers are looking to hire a Data Analyst Lead to drive data‑informed decisions across ticketing strategy across pricing, inventory management, and demand generation for our business. This role owns the analytics that power everyday decisions—from forecasting and performance reporting to optimization recommendations that increase conversion and yield. You will partner closely with Marketing, Sales and Finance stakeholders to translate data into clear actions and measurable outcomes.
#
# T

# %%
resume_url = "https://raw.githubusercontent.com/marcelalozano27-ship-it/bsan6200-assignment5/main/data/resume/resume.txt"

resume_text = requests.get(resume_url).text

resume_doc = Document(
    page_content=resume_text,
    metadata={
        "filename": "resume.txt",
        "doc_type": "resume"
    }
)

print("Loaded resume")
print(resume_doc.page_content[:500])
# Out:
# Loaded resume
# MARCELA LOZANO
# Los Angeles, CA
# marcelalozano27@gmail.com
# linkedin.com/in/marcelalozano
#
# EDUCATION
# Loyola Marymount University
# M.S. Business Analytics, Expected Aug 2026
# GPA: 4.0
#
# University of Texas at Austin
# Certification: Data Science and Data Management Systems
# Skills: SQL, Python, Tableau, Google Cloud Platform, Power BI, Microsoft Excel
#
# Loyola Marymount University
# B.A. Economics, Minor Spanish
# Magna Cum Laude, GPA: 3.89
# Valedictorian of Economics Major
#
# TECHNICAL SKILLS
# Python
# SQL
# Tableau

# %%
# ── Preview sample content ──
all_documents = jd_documents + [resume_doc]

print("Total documents including Resume:", len(all_documents))
for i in range(3):
    print(f"\n--- Job Description {i} ---")
    print(jd_documents[i].metadata)
    print(jd_documents[i].page_content[:300])
# Out:
# Total documents including Resume: 14
#
# --- Job Description 0 ---
# {'filename': 'jd_LAClippers_data_analyst_lead.txt', 'company': 'LA Clippers', 'title': 'Data Analyst Lead', 'source_url': 'https://www.nba.com/clippers/company/careers/openpositionlaclippers?gh_jid=4651394006&gh_src=9f5ba8c96us', 'date_collected': '4/27/2026', 'doc_type': 'job_description'}
#
# The LA Clippers are looking to hire a Data Analyst Lead to drive data‑informed decisions across ticketing strategy across pricing, inventory management, and demand generation for our business. This role owns the analytics that power everyday decisions—from forecasting and performance reporting to o
#
# --- Job Description 1 ---
# {'filename': 'jd_alo_production_supplyplanning_intern.txt', 'company': 'ALO', 'title': 'Production & Supply Planning Intern', 'source_url': 'https://www.aloyoga.com/pages/careers', 'date_collected': '4/26/2026', 'doc_type': 'job_description'}
#
# We are seeking a motivated and detail-oriented Production & Supply Planning Intern to assist our supply chain team in ensuring the seamless flow of goods from suppliers to our production facilities and eventually to customers. This is an exciting opportunity for someone passionate about fashion and
#
# --- Job Description 2 ---
# {'filename': 'jd_axs_associate_product_manager.txt', 'company': 'AXS', 'title': 'Associate Product Manager', 'source_url': 'https://job-boards.greenhouse.io/axs/jobs/8471910002?gh_src=p5e3kj0v2us', 'date_collected': '4/27/2026', 'doc_type': 'job_description'}
#
# AXS is seeking an Associate Product Manager conducts research, gathers customer feedback, and analyzes the product landscape to identify business opportunities. This role will collaborate with internal teams, prioritize features for the product roadmap to meet revenue and customer satisfaction goal

# %% [markdown]
# The documents pulled from GitHub contain 13 job descriptions and 1 resume.

# %% [markdown]
# ---
# <a id="3-chunking"></a>
# ## 3. Text Chunking
#
# Split your documents into chunks.
# **Required:** Try at least 2 chunking strategies, compare them quantitatively, and justify your final choice.
#
# **Hint:** JDs often have natural sections (Requirements, Responsibilities, Qualifications). Consider whether your splitter respects these boundaries.

# %%
# ── Strategy 1 ── Fixed size chunking

def chunk_text_fixed(text, chunk_size=800, overlap=100):
    chunks = []
    start = 0

    while start < len(text):
        end = start + chunk_size
        chunk = text[start:end].strip()

        if len(chunk) > 50:
            chunks.append(chunk)

        start += chunk_size - overlap

    return chunks


fixed_chunks = []

for doc in all_documents:
    chunks = chunk_text_fixed(doc.page_content, chunk_size=800, overlap=100)

    for i, chunk in enumerate(chunks):
        fixed_chunks.append({
            "text": chunk,
            "filename": doc.metadata.get("filename", ""),
            "company": doc.metadata.get("company", ""),
            "title": doc.metadata.get("title", ""),
            "doc_type": doc.metadata.get("doc_type", ""),
            "chunk_id": i,
            "chunk_strategy": "fixed_size"
        })

print("Strategy 1 chunks:", len(fixed_chunks))
print(fixed_chunks[0]["text"][:300])
# Out:
# Strategy 1 chunks: 56
# The LA Clippers are looking to hire a Data Analyst Lead to drive data‑informed decisions across ticketing strategy across pricing, inventory management, and demand generation for our business. This role owns the analytics that power everyday decisions—from forecasting and performance reporting to op

# %%
# ── Strategy 2 ──
def chunk_text_by_sentences(text, chunk_size=800, overlap_words=20):
    sentences = re.split(r'(?<=[.!?])\s+', text.strip())

    chunks = []
    current_chunk = ""

    for sentence in sentences:
        if len(current_chunk) + len(sentence) > chunk_size and current_chunk:
            chunks.append(current_chunk.strip())

            words = current_chunk.split()
            overlap_text = " ".join(words[-overlap_words:]) if len(words) > overlap_words else current_chunk
            current_chunk = overlap_text + " " + sentence
        else:
            current_chunk += (" " if current_chunk else "") + sentence

    if current_chunk.strip():
        chunks.append(current_chunk.strip())

    return [c for c in chunks if len(c) > 50]


sentence_chunks = []

for doc in all_documents:
    chunks = chunk_text_by_sentences(doc.page_content, chunk_size=800, overlap_words=20)

    for i, chunk in enumerate(chunks):
        sentence_chunks.append({
            "text": chunk,
            "filename": doc.metadata.get("filename", ""),
            "company": doc.metadata.get("company", ""),
            "title": doc.metadata.get("title", ""),
            "doc_type": doc.metadata.get("doc_type", ""),
            "chunk_id": i,
            "chunk_strategy": "sentence_aware"
        })

print("Strategy 2 chunks:", len(sentence_chunks))
print(sentence_chunks[0]["text"][:300])
# Out:
# Strategy 2 chunks: 51
# The LA Clippers are looking to hire a Data Analyst Lead to drive data‑informed decisions across ticketing strategy across pricing, inventory management, and demand generation for our business. This role owns the analytics that power everyday decisions—from forecasting and performance reporting to op

# %%
# ── Compare strategies ──
fixed_chunk_size = 800
fixed_overlap = 100

sentence_chunk_size = 800
sentence_overlap_words = 20

comparison = pd.DataFrame({
    "strategy": ["fixed_size", "sentence_aware"],
    "chunk_size": [fixed_chunk_size, sentence_chunk_size],
    "overlap": [fixed_overlap, sentence_overlap_words],
    "overlap_unit": ["characters", "words"],
    "num_chunks": [len(fixed_chunks), len(sentence_chunks)]
})

comparison
# Out:
#          strategy  chunk_size  overlap overlap_unit  num_chunks
# 0      fixed_size         800      100   characters          56
# 1  sentence_aware         800       20        words          51

# %% [markdown]
# ### Quantitative Chunking Comparison
#
# Strategy 1 used fixed-size chunking and produced 56 total chunks using a chunk size of 800 characters and 100 characters of overlap. Strategy 2 uses sentence-aware chunking and produced 51 total chunks using a chunk size of 800 and 20 words of overlap.
#
# The sentence-aware strategy produced 5 fewer chunks than the fixed-size strategy, which is about an 8.9% reduction in total chunks.
#
# The sentence-aware approach is slightly more efficient because it created fewer chunks while preserving more complete sentence-level context.
#
# ### Final Choice
#
# I chose sentence-aware chunking as the final strategy. Even though both strategies used the same general chunk size, sentence-aware chunking is better suited for job descriptions because job requirements, responsibilities, and qualifications are usually written in complete sentences or bullet points. Preserving those complete thoughts will help the retrieval step return more meaningful sections of the job description.
#
# The fixed-size strategy produced more chunks, but it may split important requirements across chunk boundaries. The sentence-aware strategy produced fewer chunks and better preserved the meaning of each section, making it the stronger option for the final job fit analysis.
#
# ### Chunking Decision
#
# **Which strategy did you choose?**
# Sentence Aware Chunking
#
# **Why?**
# I'm using sentence aware chunking to preserve complete thoughts and sentences within the job descriptions. This helps improve the quality of retrieved information. Fixed size chunking splits important requirements across chunks and is therefore less meaningful for the analysis.
#
# **Final settings (chunk_size, overlap):**
# chunk_size = 800
# overlap = 20 words

# %% [markdown]
# ---
# <a id="4-embedding"></a>
# ## 4. Embedding and Vector Store
#
# I embedded the final sentence-aware chunks and stored them in a ChromaDB vector database.
#
# **Embedding path used:** Free path
# **Embedding model:** `sentence-transformers/all-MiniLM-L6-v2`
# **Vector store:** ChromaDB
#
# I chose the free embedding path because it avoided paid embedding API calls while still supporting semantic similarity search across the resume and job descriptions.
#
# After creating the store, I ran a test similarity search to verify that relevant chunks were successfully retrieved from the database.

# %%
import logging
logging.getLogger("sentence_transformers").setLevel(logging.ERROR)
logging.getLogger("transformers").setLevel(logging.ERROR)
from sentence_transformers import SentenceTransformer
import chromadb

model = SentenceTransformer("all-MiniLM-L6-v2", device="cpu")


client = chromadb.Client()
collection = client.create_collection(name="job_fit", get_or_create=True)

# use BEST chunks
all_chunks = sentence_chunks

# create embeddings + store
texts = [chunk["text"] for chunk in all_chunks]
embeddings = model.encode(texts, show_progress_bar=False)

# add to chroma
collection.add(
    documents=texts,
    embeddings=embeddings.tolist(),
    metadatas=all_chunks,
    ids=[str(i) for i in range(len(texts))]
)

print("Vector DB created with", len(texts), "chunks")

# %%
# ── Verify: run a test similarity search ──

results = collection.query(
    query_texts=["Python SQL data analyst skills"],
    n_results=3
)

for i, doc in enumerate(results["documents"][0]):
    print(f"\n--- Result {i+1} ---")
    print(doc[:300])
# Out:
# /root/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz: 100%|██████████| 79.3M/79.3M [00:00<00:00, 104MiB/s]
# --- Result 1 ---
# Strong analytical and problem-solving skills. Proficiency in Microsoft Excel and basic data analysis techniques. Excellent written and verbal communication skills. Ability to work collaboratively in a fast-paced, team-oriented environment. Ability to work full-time onsite in Long Beach, CA. Preferre
#
# --- Result 2 ---
# Science and Data Management Systems Skills: SQL, Python, Tableau, Google Cloud Platform, Power BI, Microsoft Excel Loyola Marymount University B.A. Economics, Minor Spanish
# Magna Cum Laude, GPA: 3.89
# Valedictorian of Economics Major
#
# TECHNICAL SKILLS
# Python
# SQL
# Tableau
# Excel
# Pandas
# NumPy
# scikit-lear
#
# --- Result 3 ---
# MARCELA LOZANO
# Los Angeles, CA
# marcelalozano27@gmail.com
# linkedin.com/in/marcelalozano
#
# EDUCATION
# Loyola Marymount University
# M.S. Business Analytics, Expected Aug 2026
# GPA: 4.0
#
# University of Texas at Austin
# Certification: Data Science and Data Management Systems
# Skills: SQL, Python, Tableau, Googl

# %% [markdown]
# ### Similarity Search Evaluation
#
# The similarity search successfully retrieved the relevant chunks related to analytics, SQL, Python, Tableau, Excel, and communication skills. The retrieved results included both job description requirements as well as matching resume sections. This confirms that the embedding model and ChromaDB vector store were functioning correctly.
#
# Result 1 retrieved a job description chunk emphasizing analytical skills, Excel, communication, and teamwork requirements. Results 2 and 3 retrieved resume chunks containing technical skills such as SQL, Python, Tableau, Power BI, and educational background information. These results demonstrate that the retrieval system was able to identify semantically related content between the resume and job descriptions.
#
# The retrieved chunks were relevant to the search query “Python SQL data analyst skills,” and the vector database successfully captured semantic similarity.

# %% [markdown]
# ---
# <a id="5-analysis"></a>
# ## 5. Analysis Prompts and Chain
#
# Build 3 analysis types, each with its own prompt:
#
# 1. **Skill Gap Report:** Compare resume skills vs. JD requirements. Output matching skills, missing skills, and recommended actions.
# 2. **Keyword Alignment:** Extract key terms from a JD, check which appear in the resume, report a match rate.
# 3. **Fit Summary:** 3-4 sentence narrative assessment citing evidence from both documents.
#
# You also need to wire up the LLM and a way to pass a specific JD + resume into each prompt.
#
# **Required:** Document at least 3 prompt iterations total (across any analysis type) with rationale.
#
# **Reminder:** Prompt design must be your own work (Tier 2 — AI prohibited for this step).

# %%
# ── Initialize LLM ──
from openai import OpenAI

# load environment variables
load_dotenv(".env")

# initialize OpenAI client
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

print("LLM initialized")
# Out:
# LLM initialized

# %%
# ── Analysis 1: Skill Gap Report ──
def get_skill_gap_analysis(query):
    results = collection.query(
        query_texts=[query],
        n_results=8
    )

    context = "\n\n".join(results["documents"][0])

    prompt = f"""
You are a job fit analyzer. Use ONLY the provided context from the job description and resume.

Task:
Compare the job description against the candidate resume and create a Skill Gap Report.

Rules:
- Do not assume skills that are not stated in the resume.
- Do not say "assuming," "not confirmed," or "uncertain."
- Make a clear decision based only on the available text.
- Before listing a skill as missing, first check whether it appears anywhere in the resume context.
- If SQL, Python, Tableau, Excel, Pandas, NumPy, scikit-learn, or analytics experience appear in the resume, list them as matching skills, not gaps.
- Keep missing skills limited to truly absent or weakly demonstrated areas.
- When listing matching skills, cite exact evidence from the resume, such as tools, coursework, projects, or work experience.
- Provide practical recommendations for closing each gap.

Return the response in this structure:

1. Matching skills found in the resume
- Skill:
- Resume evidence:
- Why it matches the JD:

2. Required skills from the job description
- List the major required skills from the JD.

3. Missing or weak skills
- Gap:
- Why it is a gap:

4. Recommended actions to close each gap
- Gap:
- Recommended action:

Context:
{context}
"""

    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {
                "role": "system",
                "content": "You compare resumes to job descriptions using only the provided text."
            },
            {
                "role": "user",
                "content": prompt
            }
        ],
        temperature=0.2
    )

    return response.choices[0].message.content

# %%
analysis = get_skill_gap_analysis(
    "resume skills SQL Python Tableau Excel candidate experience"
)
print(analysis)
# Out:
# 1. **Matching skills found in the resume**
# - **Skill:** SQL
# - **Resume evidence:** "Skills: SQL, Python, Tableau, Google Cloud Platform, Power BI, Microsoft Excel"
# - **Why it matches the JD:** The job description requires SQL for querying and analyzing datasets, which is explicitly mentioned in the candidate's skills.
#
# - **Skill:** Python
# - **Resume evidence:** "Skills: SQL, Python, Tableau, Google Cloud Platform, Power BI, Microsoft Excel"
# - **Why it matches the JD:** Python is listed as a skill, aligning with the job's preference for hands-on ML experience.
#
# - **Skill:** Tableau
# - **Resume evidence:** "Skills: SQL, Python, Tableau, Google Cloud Platform, Power BI, Microsoft Excel"
# - **Why it matches the JD:** The job description mentions data visualization tools such as Tableau, which the candidate has experience with.
#
# - **Skill:** Excel
# - **Resume evidence:** "Proficiency in Microsoft Excel and basic data analysis techniques."
# - **Why it matches the JD:** The job description emphasizes strong proficiency in Excel, which the candidate demonstrates.
#
# - **Skill:** Data visualization
# - **Resume evidence:** "Solid experience in data visualization (powerpoint)"
# - **Why it matches the JD:** The job requires experience with BI/dashboarding skills, which includes data visualization.
#
# 2. **Required skills from the job description**
# - Advanced SQL and BI/dashboarding skills (Power BI, Tableau, or similar)
# - Hands-on ML experience (regression/forecasting, clustering/segmentation)
# - Strong business partnering ability
# - Ability to structure ambiguous problems and connect data to business decisions
# - Strong written and verbal communication skills
# - High attention to detail and strong organization skills
#
# 3. **Missing or weak skills**
# - **Gap:** Hands-on ML experience (specifically in regression/forecasting, clustering/segmentation)
# - **Why it is a gap:** While the candidate has experience with machine learning techniques, the job description specifically emphasizes hands-on experience in regression/forecasting and clustering/segmentation, which is not explicitly demonstrated in the resume.
#
# - **Gap:** Strong business partnering ability
# - **Why it is a gap:** The job description highlights the need for strong business partnering skills, particularly in influencing decisions through data, which is not clearly evidenced in the candidate's experience.
#
# 4. **Recommended actions to close each gap**
# - **Gap:** Hands-on ML experience (specifically in regression/forecasting, clustering/segmentation)
# - **Recommended action:** Engage in projects or coursework that focus specifically on regression and forecasting models, as well as clustering techniques, to gain practical experience and demonstrate proficiency in these areas.
#
# - **Gap:** Strong business partnering ability
# - **Recommended action:** Seek opportunities to collaborate with cross-functional teams or participate in projects that require direct interaction with business stakeholders to enhance business acumen and demonstrate the ability to influence decisions through data.

# %%
# ── Analysis 2: Keyword Alignment ──
def get_keyword_alignment(query):
    results = collection.query(
        query_texts=[query],
        n_results=10
    )

    docs = results["documents"][0]

    # Prioritize resume chunks so the model sees your actual skills
    resume_chunks = [
        d for d in docs
        if "MARCELA" in d or "TECHNICAL SKILLS" in d or "EDUCATION" in d or "SQL" in d
    ]
    jd_chunks = [d for d in docs if d not in resume_chunks]

    context = "\n\n".join(resume_chunks + jd_chunks)

    prompt = f"""
You are a job fit analyzer. Use ONLY the provided job description and resume context.

Task:
Create a Keyword Alignment analysis comparing the job description keywords against the resume.

Instructions:
- Extract 12 to 15 important keywords or phrases from the job description.
- For each keyword, determine whether it appears directly in the resume, appears as a semantic equivalent, or is missing.
- Do not mark SQL, Python, Tableau, Excel, analytics, or data visualization as missing if they appear anywhere in the resume context.
- Calculate an overall keyword match percentage:
  match percentage = (direct matches + semantic matches) / total keywords * 100
- Be specific and evidence-based.

Return the output in this structure:

1. Keyword Alignment Table
Columns:
- JD Keyword/Phrase
- Resume Match Status: Direct Match, Semantic Match, or Missing
- Resume Evidence
- Notes

2. Overall Keyword Match Percentage
Show the calculation.

3. Brief Interpretation
Write 3 to 4 sentences explaining what the match percentage means for the candidate's fit.

Context:
{context}
"""

    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {
                "role": "system",
                "content": "You compare job description keywords to resume evidence using only provided text."
            },
            {
                "role": "user",
                "content": prompt
            }
        ],
        temperature=0.2
    )

    return response.choices[0].message.content

# %%
keyword_analysis = get_keyword_alignment(
    "Data Analyst job requirements keywords SQL Python Tableau Excel analytics pricing forecasting"
)

print(keyword_analysis)
# Out:
# ### 1. Keyword Alignment Table
#
# | JD Keyword/Phrase                                      | Resume Match Status | Resume Evidence                                                                 | Notes                                                                                      |
# |-------------------------------------------------------|---------------------|--------------------------------------------------------------------------------|--------------------------------------------------------------------------------------------|
# | Analytics experience                                   | Direct Match        | 5–7+ years of analytics experience with a focus on pricing, revenue optimization | Directly mentioned in the job description and resume.                                      |
# | Pricing optimization                                   | Missing             | N/A                                                                            | No direct mention of pricing optimization in the resume.                                   |
# | Revenue forecasting                                    | Missing             | N/A                                                                            | No direct mention of revenue forecasting in the resume.                                    |
# | Demand generation                                      | Missing             | N/A                                                                            | No direct mention of demand generation in the resume.                                      |
# | Business intelligence tools (Tableau, Power BI)      | Direct Match        | Skills: Tableau, Power BI                                                      | Directly mentioned in both the job description and resume.                                 |
# | Data visualization                                     | Direct Match        | Data visualization                                                              | Directly mentioned in both the job description and resume.                                 |
# | Collaboration with stakeholders                       | Direct Match        | Partnered with Fortune 100 strategy, consulting, and product teams            | Directly mentioned in the resume.                                                           |
# | Strong business acumen                                 | Semantic Match      | Strong analytical and problem-solving skills                                    | Implies business acumen through analytical skills.                                          |
# | Executive-ready narratives                             | Missing             | N/A                                                                            | No direct mention of creating executive-ready narratives in the resume.                    |
# | A/B testing                                           | Semantic Match      | A/B testing (conceptual)                                                      | Mentioned in the resume as a conceptual understanding.                                     |
# | Data-driven insights                                   | Semantic Match      | Generated strategy recommendations for marketing optimization                  | Implies data-driven insights through strategy recommendations.                              |
# | Attention to detail                                   | Direct Match        | Unflagging attention to detail                                                 | Directly mentioned in the resume.                                                           |
# | Communication skills                                   | Direct Match        | Excellent written and verbal communication skills                               | Directly mentioned in both the job description and resume.                                 |
# | Experience with SQL                                   | Direct Match        | Skills: SQL                                                                     | Directly mentioned in both the job description and resume.                                 |
# | Fast-paced environment                                 | Direct Match        | Ability to work collaboratively in a fast-paced, team-oriented environment      | Directly mentioned in the resume.                                                           |
#
# ### 2. Overall Keyword Match Percentage
#
# - Total Keywords: 15
# - Direct Matches: 7
# - Semantic Matches: 4
# - Missing: 4
#
# **Match Percentage Calculation:**
# \[
# \text{Match Percentage} = \left( \frac{\text{Direct Matches} + \text{Semantic Matches}}{\text{Total Keywords}} \right) \times 100
# \]
# \[
# \text{Match Percentage} = \left( \frac{7 + 4}{15} \right) \times 100 = \left( \frac{11}{15} \right) \times 100 \approx 73.33\%
# \]
#
# ### 3. Brief Interpretation
#
# The candidate has a keyword match percentage of approximately 73.33%, indicating a strong alignment with the job description. The presence of direct matches in critical areas such as analytics experience, data visualization, and collaboration with stakeholders suggests that the candidate possesses relevant skills and experiences that are highly valued for the role. However, the absence of specific keywords related to pricing optimization and revenue forecasting may indicate areas for further development or experience that could enhance the candidate's fit for this position. Overall, the candidate appears to be a strong contender for the role, with a solid foundation in analytics and data management.

# %%
# ── Analysis 3: Fit Summary ──
def get_fit_summary(query):
    results = collection.query(
        query_texts=[query],
        n_results=8
    )

    docs = results["documents"][0]

    # prioritize resume content
    resume_chunks = [
        d for d in docs
        if "MARCELA" in d or "TECHNICAL SKILLS" in d or "EDUCATION" in d or "SQL" in d
    ]
    jd_chunks = [d for d in docs if d not in resume_chunks]

    context = "\n\n".join(resume_chunks + jd_chunks)

    prompt = f"""
You are a hiring analyst evaluating candidate fit.

Task:
Provide a clear, concise Fit Summary comparing the candidate resume to the job description.

Instructions:
- Use ONLY the provided context.
- Be decisive and do not say "uncertain" or "assuming."
- Recognize existing strengths such as SQL, Python, Tableau, Excel, analytics experience if present.
- Focus on overall fit, not just listing skills.

Return the output in this structure:

1. Overall Fit Score (0–100)
- Give a numeric score
- Brief justification

2. Strengths
- 3–5 key strengths that align with the role

3. Weaknesses / Gaps
- 2–4 meaningful gaps (focus on real gaps, not tools already present)

4. Final Hiring Recommendation
- Strong Yes, Yes, Maybe, or No
- 2–3 sentence explanation

Context:
{context}
"""

    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {
                "role": "system",
                "content": "You evaluate candidate fit using only provided resume and job description text."
            },
            {
                "role": "user",
                "content": prompt
            }
        ],
        temperature=0.2
    )

    return response.choices[0].message.content

# %%
fit_summary = get_fit_summary(
    "Data Analyst job fit SQL Python Tableau Excel analytics pricing forecasting"
)

print(fit_summary)
# Out:
# 1. Overall Fit Score: 85
# - Marcela demonstrates a strong alignment with the job requirements, particularly in analytics, SQL, Python, and data visualization tools like Tableau and Power BI. Her experience in developing ETL pipelines and performing customer segmentation analysis is relevant to the role's focus on data-informed decision-making.
#
# 2. Strengths
# - Proficient in SQL, Python, Tableau, and Excel, which are essential for data analysis and visualization.
# - Experience in building ETL pipelines and conducting advanced analytics, including NLP and customer segmentation.
# - Strong academic background with a 4.0 GPA in her M.S. program and relevant certifications in Data Science.
# - Proven ability to translate complex data insights into actionable business strategies, demonstrated through her consulting experience.
#
# 3. Weaknesses / Gaps
# - Limited direct experience in pricing, revenue optimization, or e-commerce analytics, which are critical for the role.
# - No explicit mention of experience with forecasting, inventory management, or capacity planning concepts.
# - Lack of hands-on experience with ERP or MRP systems, which could be beneficial for the position.
#
# 4. Final Hiring Recommendation: Yes
# - Marcela is a strong candidate for the Data Analyst Lead position, with relevant technical skills and a solid foundation in analytics. While she has some gaps in specific industry experience, her analytical capabilities and proven track record in consulting make her a valuable addition to the team.

# %% [markdown]
# ## Prompt Iteration Log
#
# Document at least 3 total iterations across any of the analysis types.
#
# **Iteration 1:**
#
# **Analysis:** Skill Gap Report
#
# **What changed and why?**
# The initial prompt asked the model to identify missing skills, transferable skills, and recommendations based on the resume and job description. However, the output occasionally labeled skills such as SQL, Tableau, and Power BI as missing even when they were clearly listed in the resume.
#
# To improve the accuracy, the final prompt instructed the model to verify resume evidence before identifying a skill gap. This helped reduce the number of false positives and produced more realistic gaps focused on advanced Excel, forecasting, pricing/revenue optimization, experimentation platforms, and business partnering.
#
# **What Improved**:
# The final prompt improved accuracy by forcing the model to check resume evidence before labeling a skill as missing. The output improved because it followed the resume content more closely and reduced incorrect skill gaps.
#
#
# **Iteration 2:**
#
#
# **Analysis:** Skill Gap Report
#
# **What changed and why?**
# The second version of the prompt added more explicit section formatting for:
# - Missing Skills
# - Transferable Skills
# - Recommendations
# The model was mixing strengths and weaknesses together which made the comparison harder to evaluate.
#
# **What Improved**:
# The responses became a lot easier to read with more structure and stronger actionable guidance. It also improved consistency across all analyzed job descriptions.
#
#
# **Iteration 3:**
#
#
# **Analysis:** Skill Gap Report
#
# **What changed and why?**
# I added that years of experience should not be assumed unless it is explicitly stated in the resume. The earlier versions were inferring experience levels or overstating them.
#
# **What Improved**:
# The final outputs became more grounded in the source documents and reduced hallucinated assumptions about experience level and technical depth.

# %% [markdown]
# ---
# <a id="6-comparison"></a>
# ## 6. Zero-shot vs. Few-shot Comparison
#
# Pick one of your 3 analysis types. Create a few-shot version by adding 1-2 example input/output pairs to the prompt. Run both versions on the same JD and compare outputs.
#
# **Reminder:** You must write the few-shot examples yourself (Tier 2).

# %%
# ── Few-shot version of your Skill Gap analysis ──


few_shot_prompt = """
You are an AI career assistant.

Example 1:
Resume:
- Experience with Python, SQL, Tableau, and client analytics
- Worked with cross functional teams
- Built dashboards and reports

Job Description:
- Requires Python, SQL, Power BI, and machine learning experience

Output:
Missing Skills:
- Power BI
- Machine Learning

Transferable Skills:
- Tableau experience demonstrates data visualization background
- Analytics reporting experience transfers well to BI tasks

Recommendation:
Candidate should highlight analytical project experience and mention any background or exposure to predictive modeling.


Example 2:
Resume:
- Experience with Excel, operations, and customer management
- Conducted research and business reporting

Job Description:
- Requires stakeholder communication, data analysis, and dashboard reporting

Output:
Missing Skills:
- Dashboard software specifically mentioned in the JD

Transferable Skills:
- Research and reporting experience aligns with analytical communication requirements
- Customer management supports stakeholder collaboration

Recommendation:
Candidate should emphasize reporting tools and analytical communication experience.


Now analyze the following resume and job description.

Resume:
{resume}

Job Description:
{job_description}

Provide:
1. Missing Skills
2. Transferable Skills
3. Recommendations
"""

# %%
# ── Run both on the same JD, display side by side ──
# --- Run zero-shot vs few-shot on same JD ---

sample_jd = jd_documents[0].page_content
sample_resume = resume_doc.page_content

# Zero-shot
zero_shot_prompt = f"""
Analyze the candidate's skill gaps compared to the job description.

Resume:
{sample_resume}

Job Description:
{sample_jd}

Provide:
1. Missing Skills
2. Transferable Skills
3. Recommendations
"""

zero_shot_response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {
            "role": "system",
            "content": "You compare resumes to job descriptions using only the provided text."
        },
        {
            "role": "user",
            "content": zero_shot_prompt
        }
    ],
    temperature=0.2
)

# Few-shot
formatted_few_shot = few_shot_prompt.format(
    resume=sample_resume,
    job_description=sample_jd
)

few_shot_response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {
            "role": "system",
            "content": "You are an AI career assistant."
        },
        {
            "role": "user",
            "content": formatted_few_shot
        }
    ],
    temperature=0.2
)

print("========== ZERO-SHOT OUTPUT ==========\n")
print(zero_shot_response.choices[0].message.content)

print("\n\n========== FEW-SHOT OUTPUT ==========\n")
print(few_shot_response.choices[0].message.content)
# Out:
# ========== ZERO-SHOT OUTPUT ==========
#
# ### 1. Missing Skills
# - **Experience Level**: The job requires 5–7+ years of analytics experience, while the candidate has approximately 3 years of relevant experience.
# - **Pricing Strategy and Elasticity Analysis**: The job description specifically mentions the need for experience with pricing strategy and elasticity analysis, which is not explicitly stated in the candidate's resume.
# - **Advanced SQL and BI Skills**: While the candidate lists SQL and BI tools (Power BI, Tableau), the job description emphasizes advanced SQL and proven ability to model data and tell a clear story with visuals, which may require more depth than what is demonstrated.
# - **Hands-on ML Experience**: The job requires hands-on experience with regression/forecasting, clustering/segmentation, and propensity/uplift modeling, which is not clearly highlighted in the candidate's experience.
# - **Business Partnering Ability**: The role emphasizes strong business partnering with Sales, Marketing, and Finance, which is not explicitly detailed in the candidate's experience.
# - **Experimentation Platforms**: The job mentions familiarity with experimentation platforms for A/B testing and uplift/propensity modeling, which is only conceptually mentioned in the candidate's resume.
#
# ### 2. Transferable Skills
# - **Data Analysis and Visualization**: The candidate has experience in data visualization using Tableau and Power BI, which aligns with the job's requirement for dashboarding skills.
# - **ETL and Data Management**: The candidate has built ETL pipelines and has experience in data cleaning and preprocessing, which is relevant for the data quality and performance reporting aspects of the job.
# - **NLP and Machine Learning**: The candidate's experience with machine learning models and NLP can be beneficial for analyzing customer behavior and demand forecasting.
# - **Communication Skills**: The candidate has experience presenting analytical findings and generating business insights, which is essential for the role's requirement for clear narratives and recommendations.
# - **Analytical Tools**: Proficiency in tools like Python, SQL, and Tableau is relevant to the job description, which requires technical skills for data analysis and reporting.
#
# ### 3. Recommendations
# - **Gain More Experience**: The candidate should seek opportunities to gain more experience in analytics, particularly in pricing strategy and revenue optimization, to meet the 5–7+ years requirement.
# - **Focus on Pricing and Elasticity Analysis**: The candidate should consider taking courses or certifications that focus on pricing strategies and elasticity analysis to fill this gap.
# - **Enhance SQL and BI Skills**: The candidate should work on advanced SQL techniques and deepen their knowledge of BI tools to better meet the job's requirements for data modeling and storytelling.
# - **Develop Business Partnering Skills**: The candidate should seek roles or projects that involve collaboration with Sales, Marketing, and Finance teams to strengthen their business partnering abilities.
# - **Hands-on ML Projects**: Engaging in projects that specifically involve regression/forecasting and propensity modeling will help the candidate demonstrate the required hands-on ML experience.
# - **Familiarize with Experimentation Platforms**: The candidate should gain practical experience with A/B testing and experimentation platforms to align with the job's requirements.
#
#
# ========== FEW-SHOT OUTPUT ==========
#
# ### 1. Missing Skills:
# - Experience specifically in pricing strategy and elasticity analysis.
# - 5–7+ years of analytics experience in ecommerce/ticketing analytics.
# - Hands-on familiarity with experimentation platforms beyond A/B testing (e.g., multivariate testing).
# - Advanced SQL skills tailored to pricing and revenue optimization.
# - Strong business partnering experience with a focus on influencing decisions in Sales/Marketing/Finance.
#
# ### 2. Transferable Skills:
# - **Data Visualization**: Experience with Tableau and Power BI aligns well with the requirement for advanced BI/dashboarding skills.
# - **Machine Learning**: Hands-on experience with regression, clustering, and segmentation models can translate to the ML experience needed for pricing and demand actions.
# - **A/B Testing**: Conceptual knowledge of A/B testing and experiment design is relevant for running test-and-learn programs.
# - **Stakeholder Communication**: Experience in translating complex analytical findings into actionable insights for clients demonstrates strong communication skills, which is crucial for partnering with Sales, Marketing, and Finance.
# - **Analytical Reporting**: Experience in building dashboards and conducting performance reporting aligns with the role's focus on performance metrics and reporting.
#
# ### 3. Recommendations:
# - **Highlight Relevant Experience**: Emphasize any specific projects or experiences that relate to pricing strategy, revenue optimization, or ticketing analytics, even if they were not the primary focus of previous roles.
# - **Quantify Achievements**: Where possible, include metrics or outcomes from past projects that demonstrate the impact of your analytical work, especially in terms of revenue generation or cost savings.
# - **Showcase Business Partnering Skills**: Provide examples of how you have successfully collaborated with cross-functional teams, particularly in Sales, Marketing, and Finance, to influence decisions based on data.
# - **Detail Technical Proficiencies**: Consider elaborating on your SQL skills, particularly any experience with advanced querying techniques that relate to pricing and revenue analysis.
# - **Express Adaptability**: Given the dynamic environment mentioned in the job description, highlight your ability to learn quickly and adapt to new tools or methodologies in analytics.

# %% [markdown]
# ### Zero-shot vs. Few-shot Analysis
#
# **Which analysis type did you compare?**
# I compared the Skill Gap Analysis using zero shot prompt and few shot prompt.
#
# **Which performed better?**
#
# The few shot analysis performed the best overall.
#
# **Why? (use specific examples from the outputs above)**
#
# The output from the zero shot analysis was more detailed but it was not necessarily better than the few shot. It inferred experience levels and privdied more generalized technical gaps without actually referencing the context from the provided resume. It also was more repetitive in the recommendations it provided for the candidate.
#
# On the other hand, the few shot prompt had more structured and focused results. The examples provided in the prompt helped guide the model towards producing an output in the level of detail expected. The following are examples of where the few shot version connected the job descriptions more specifically to the experience listed in the resume:
# - "Experience at Coleman Research working with strategy...": In this example the few shot model connected the experience in the resume to "collaboration with cross functional teams". (The zero shot model gave a more general description saying Marcela has experience in presenting analytical findings.
# - "Quantify contributions", "Emphasize her SQL and BI skills in the context of pricing and revenue optimization", "Marcela should prepare examples that showcase her ability to influence decisions through data": These are three examples where the few shot analysis provided specific and actionable recommendations for a stronger resume
#
# Overall, the few shot model provided more specific regarding the resume uploaded as opposed to relying on more general feedback for a candidate applying to the role. The zero shot model provided more general feedback like "network with professionals in the field" or "consider further education". This feedback is not as helpful for signaling the actions to be taken. Additionally, the few shot model was less repetitive and provided a cleaner output for readability.

# %% [markdown]
# ---
# <a id="7-evaluation"></a>
# ## 7. Evaluation
#
# Run all 3 analysis types on your **top 3 target JDs** (9 total analyses).
#
# For each, score:
# - **Retrieval relevance:** Did it pull the right JD sections? (Yes/Partial/No)
# - **Skill identification accuracy:** Are identified skills/gaps correct? (count correct vs. incorrect)
# - **Actionability:** Are recommendations specific and useful? (1-5)
# - **Faithfulness:** Does output stick to document content? (Faithful/Partial/Hallucinated)
#
# **Reminder:** Evaluation must be your own work (Tier 2 — AI prohibited).

# %%
# __ Run 9 analyses (3 JDs x 3 analysis types) __

top_jds = jd_documents[:3]

evaluation_results = []

for i, jd in enumerate(top_jds):

    jd_text = jd.page_content
    jd_name = jd.metadata.get("title", f"JD {i+1}")

    # ---------- Fit Summary ----------
    fit_prompt = f"""
    Analyze the candidate's overall fit for this role.

    Resume:
    {sample_resume}

    Job Description:
    {jd_text}

    Provide:
    1. Overall Fit
    2. Strengths
    3. Weaknesses
    """

    fit_response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {
                "role": "system",
                "content": "You are a hiring analyst evaluating candidate fit."
            },
            {
                "role": "user",
                "content": fit_prompt
            }
        ],
        temperature=0.2
    )

    evaluation_results.append({
        "JD": jd_name,
        "Analysis": "Fit Summary",
        "Output": fit_response.choices[0].message.content
    })

    # ---------- Keyword Alignment ----------
    keyword_prompt = f"""
    Compare the resume and job description.

    Resume:
    {sample_resume}

    Job Description:
    {jd_text}

    Provide:
    1. Matching Keywords
    2. Missing Keywords
    3. Important Technical Skills
    """

    keyword_response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {
                "role": "system",
                "content": "You are a job fit analyzer comparing keywords."
            },
            {
                "role": "user",
                "content": keyword_prompt
            }
        ],
        temperature=0.2
    )

    evaluation_results.append({
        "JD": jd_name,
        "Analysis": "Keyword Alignment",
        "Output": keyword_response.choices[0].message.content
    })

    # ---------- Skill Gap Analysis ----------
    skill_gap_prompt = f"""
    Analyze the candidate's skill gaps compared to the job description.

    Resume:
    {sample_resume}

    Job Description:
    {jd_text}

    Do not assume years of experience unless explicitly stated.

    Provide:
    1. Missing Skills
    2. Transferable Skills
    3. Recommendations
    """

    skill_gap_response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {
                "role": "system",
                "content": "You are a job fit analyzer creating a skill gap report."
            },
            {
                "role": "user",
                "content": skill_gap_prompt
            }
        ],
        temperature=0.2
    )

    evaluation_results.append({
        "JD": jd_name,
        "Analysis": "Skill Gap Analysis",
        "Output": skill_gap_response.choices[0].message.content
    })

print(f"Completed {len(evaluation_results)} analyses.")
# Out:
# Completed 9 analyses.

# %%
# ── Summarize evaluation results ──

for result in evaluation_results:

    print("=" * 80)
    print(f"JD: {result['JD']}")
    print(f"Analysis Type: {result['Analysis']}")
    print("-" * 80)
    print(result["Output"])
    print("\n")
# Out:
# ================================================================================
# JD: Data Analyst Lead
# Analysis Type: Fit Summary
# --------------------------------------------------------------------------------
# ### 1. Overall Fit
# Marcela Lozano appears to be a strong candidate for the Data Analyst Lead position with the LA Clippers. Her educational background in Business Analytics and Economics, combined with her technical skills and relevant professional experience, align well with the requirements of the role. She has demonstrated proficiency in data analysis, forecasting, and performance reporting, which are critical for driving data-informed decisions in ticketing strategy. Additionally, her experience in collaborating with cross-functional teams and presenting insights to stakeholders positions her well for the business partnering aspect of the role.
#
# ### 2. Strengths
# - **Educational Background**: Marcela holds a Master's degree in Business Analytics (in progress) and a Bachelor's degree in Economics, which provides her with a solid foundation in quantitative analysis and economic principles relevant to pricing and revenue optimization.
# - **Technical Skills**: She possesses advanced skills in SQL, Python, Tableau, and other analytics tools, which are essential for building dashboards, performing data analysis, and creating visual narratives. Her experience with machine learning techniques (regression, clustering, and A/B testing) aligns well with the job's requirements.
# - **Professional Experience**: Her role as a Strategy & Analytics Consultant at AutoDive showcases her ability to develop data-driven strategies and perform customer segmentation analysis, which is directly applicable to the ticketing and pricing strategies at the LA Clippers. Additionally, her experience in managing client relationships and delivering insights for investment decisions demonstrates her capability to influence business outcomes through data.
# - **Project Experience**: Marcela has worked on relevant projects, such as customer segmentation and sentiment analysis, which highlight her ability to translate data into actionable insights. Her experience with A/B testing and model evaluation further supports her fit for the role.
# - **Communication Skills**: Her experience in presenting analytical findings and collaborating with various teams indicates strong communication skills, which are crucial for translating insights into clear actions for stakeholders.
#
# ### 3. Weaknesses
# - **Experience Level**: While Marcela has relevant experience, she has only around 2-3 years of analytics experience, which is below the 5-7 years typically required for this role. This may raise concerns about her ability to lead and own analytics initiatives independently.
# - **Specific Industry Experience**: Although she has experience in strategy and analytics, her background does not specifically highlight experience in the sports or entertainment industry, which may be beneficial for understanding the unique dynamics of ticketing and fan engagement.
# - **Leadership Experience**: The role requires a lead position, and while Marcela has experience in consulting and client management, there is limited evidence of her having led teams or projects in a formal capacity, which could be a consideration for the hiring team.
# - **Pricing Strategy Experience**: The job description emphasizes the need for experience in pricing strategy and elasticity analysis in a high-SKU or high-velocity environment. Marcela's resume does not explicitly mention experience in these areas, which could be a gap compared to other candidates.
#
# In summary, Marcela Lozano is a strong candidate with relevant skills and experience, but her relative lack of years in the field and specific industry experience may be potential concerns for the hiring team.
#
#
# ================================================================================
# JD: Data Analyst Lead
# Analysis Type: Keyword Alignment
# --------------------------------------------------------------------------------
# ### 1. Matching Keywords
# - **Analytics Experience**: Both the resume and job description emphasize analytics experience.
# - **SQL**: Mentioned in both the resume and job description as a required skill.
# - **Dashboarding**: Both the resume (Tableau, Power BI) and job description (BI/dashboarding skills) reference dashboard creation.
# - **Forecasting**: The resume mentions demand forecasting and revenue analysis, aligning with the job description's need for forecasting demand and revenue.
# - **A/B Testing**: Both the resume and job description highlight experience with A/B testing.
# - **Collaboration with Teams**: The resume mentions collaboration with various teams, which aligns with the job description's emphasis on partnering with Sales, Marketing, and Finance.
# - **Data Quality**: The resume discusses data cleaning and preprocessing, which relates to the job description's focus on championing data quality.
# - **Communication Skills**: Both emphasize the importance of clear communication and presentation of insights.
#
# ### 2. Missing Keywords
# - **Pricing Strategy**: The job description specifically mentions experience with pricing strategy and elasticity analysis, which is not explicitly stated in the resume.
# - **Revenue Optimization**: While the resume discusses revenue-related analytics, it does not specifically mention revenue optimization.
# - **High-SKU or High-Velocity Environment**: The job description references experience in such environments, which is not present in the resume.
# - **Business Partnering**: The job description emphasizes strong business partnering ability, which is not explicitly highlighted in the resume.
# - **Experimentation Platforms**: The job description mentions familiarity with experimentation platforms, which is not detailed in the resume.
# - **Propensity/Uplift Modeling**: This specific terminology is not found in the resume.
#
# ### 3. Important Technical Skills
# - **SQL**: Advanced SQL skills are crucial for data manipulation and reporting.
# - **BI Tools (Power BI, Tableau)**: Proficiency in these tools is essential for building dashboards and visualizing data.
# - **Machine Learning**: Hands-on experience with regression, forecasting, clustering, and segmentation is important for translating model results into actionable insights.
# - **Python or R**: Familiarity with these programming languages for ad-hoc analysis and forecasting is necessary.
# - **A/B Testing**: Experience in designing and analyzing A/B tests is critical for optimizing pricing and promotions.
# - **Data Quality Assurance**: Skills in defining KPIs and ensuring data accuracy are important for reliable reporting.
#
# Overall, while Marcela Lozano has a strong background in analytics and relevant technical skills, there are specific areas in the job description that are not fully addressed in her resume, particularly around pricing strategy and revenue optimization.
#
#
# ================================================================================
# JD: Data Analyst Lead
# Analysis Type: Skill Gap Analysis
# --------------------------------------------------------------------------------
# ### Skill Gap Report for Marcela Lozano
#
# #### 1. Missing Skills
# Based on the job description for the Data Analyst Lead position at the LA Clippers, the following skills are identified as missing or underrepresented in Marcela's resume:
#
# - **Pricing Strategy and Elasticity Analysis**: The job requires experience specifically in pricing strategy and elasticity analysis, which is not mentioned in Marcela's resume.
# - **Advanced SQL Skills**: While Marcela lists SQL as a skill, the job description emphasizes "advanced SQL" capabilities, which may imply a deeper level of expertise in complex queries, optimization, and data modeling.
# - **Ecommerce/Ticketing Analytics**: There is no mention of experience in ecommerce or ticketing analytics, which is crucial for the role.
# - **Hands-on ML Experience**: The job description specifies the need for hands-on experience with regression/forecasting and uplift modeling, which is not explicitly detailed in Marcela's resume.
# - **Business Partnering with Sales/Marketing/Finance**: While Marcela has experience in client management and analytics, the job emphasizes a strong business partnering ability specifically with Sales, Marketing, and Finance, which may require more direct experience in those areas.
# - **Experimentation Platforms**: The job requires familiarity with experimentation platforms for A/B testing and uplift/propensity modeling, which is not explicitly mentioned in her experience.
#
# #### 2. Transferable Skills
# Marcela possesses several transferable skills that align well with the requirements of the Data Analyst Lead position:
#
# - **Data Visualization**: Proficiency in Tableau and Power BI, which are essential for building and maintaining dashboards.
# - **Analytical Skills**: Experience in customer segmentation, sentiment analysis, and performance reporting, which can be applied to demand forecasting and performance tracking.
# - **Machine Learning**: Knowledge of various machine learning techniques (e.g., clustering, regression modeling) that can be leveraged for demand analysis and optimization recommendations.
# - **Communication Skills**: Experience in presenting analytical findings and collaborating with teams, which is crucial for translating insights into actionable recommendations.
# - **ETL Pipelines**: Experience in building ETL pipelines, which is relevant for data preparation and ensuring data quality.
#
# #### 3. Recommendations
# To enhance her fit for the Data Analyst Lead position at the LA Clippers, Marcela should consider the following recommendations:
#
# - **Gain Experience in Pricing Strategy**: Seek opportunities or projects that involve pricing strategy and elasticity analysis to build relevant experience.
# - **Enhance SQL Skills**: Consider advanced SQL training or projects that require complex data manipulation and modeling to meet the "advanced" requirement.
# - **Focus on Ecommerce Analytics**: Look for internships or projects related to ecommerce or ticketing analytics to gain industry-specific experience.
# - **Develop Hands-on ML Experience**: Engage in projects that specifically involve regression/forecasting and uplift modeling to strengthen her machine learning portfolio.
# - **Strengthen Business Partnering Skills**: Actively seek roles or projects that involve collaboration with Sales, Marketing, and Finance teams to enhance her business partnering capabilities.
# - **Familiarize with Experimentation Platforms**: Gain experience with A/B testing and uplift modeling through online courses or practical projects to meet the job's requirements.
#
# By addressing these skill gaps and leveraging her transferable skills, Marcela can significantly improve her candidacy for the Data Analyst Lead position at the LA Clippers.
#
#
# ================================================================================
# JD: Production & Supply Planning Intern
# Analysis Type: Fit Summary
# --------------------------------------------------------------------------------
# ### 1. Overall Fit
# Marcela Lozano appears to be a strong candidate for the Production & Supply Planning Intern role, despite her background being more focused on data analytics and business strategy rather than fashion or supply chain management specifically. Her analytical skills, experience with data management, and ability to communicate effectively with stakeholders align well with the responsibilities outlined in the job description. However, her lack of direct experience in supply chain operations or the fashion industry may be a limiting factor.
#
# ### 2. Strengths
# - **Strong Educational Background**: Marcela has a solid academic foundation with a Master's in Business Analytics and a Bachelor's in Economics, both of which provide her with a strong analytical and quantitative skill set.
# - **Technical Skills**: She possesses a wide range of technical skills, including proficiency in Excel, SQL, and data visualization tools like Tableau and Power BI. These skills are valuable for data entry and process improvement tasks in supply chain management.
# - **Analytical Experience**: Her experience as a Strategy & Analytics Consultant demonstrates her ability to analyze data, build ETL pipelines, and perform customer segmentation, which can be beneficial in understanding vendor forecasting and improving supply chain processes.
# - **Communication Skills**: Marcela's experience in client management and collaboration with various teams indicates strong communication skills, which are essential for liaising with vendors and supporting team efforts.
# - **Problem-Solving Ability**: Her history of improving workflows and contributing to successful projects shows a proactive approach to problem-solving and process improvement.
#
# ### 3. Weaknesses
# - **Lack of Direct Supply Chain Experience**: While Marcela has relevant analytical experience, she does not have direct experience in supply chain operations or the fashion industry, which may limit her understanding of specific industry challenges and practices.
# - **Limited Knowledge of Fashion Industry**: The job description emphasizes a passion for fashion, which is not evident in her resume. This could be a potential gap in her fit for a role specifically focused on fashion supply chain operations.
# - **Internship Level Position**: As a candidate with advanced degrees and significant professional experience, she may be overqualified for an internship role, which could lead to concerns about her long-term commitment or job satisfaction.
# - **Basic Excel Skills Requirement**: While she is proficient in Excel, the job description specifically mentions "basic Excel skills." This could imply that her advanced skills may not be fully utilized in this role, potentially leading to disengagement.
#
# In summary, while Marcela has many strengths that align with the role, her lack of direct supply chain experience and specific industry knowledge may pose challenges in her fit for this internship.
#
#
# ================================================================================
# JD: Production & Supply Planning Intern
# Analysis Type: Keyword Alignment
# --------------------------------------------------------------------------------
# ### 1. Matching Keywords
# - **Data Entry**: Mentioned in both the job description and the resume.
# - **Communication**: Both the job description and the resume emphasize the importance of communication skills.
# - **Organizational Skills**: Highlighted in both the job description and the resume.
# - **Attention to Detail**: Both documents stress the need for attention to detail.
# - **Problem Solver**: The job description mentions a problem solver, while the resume indicates experience in analyzing and improving processes.
# - **Teamwork**: Both the job description and the resume reflect a collaborative approach.
#
# ### 2. Missing Keywords
# - **Supply Chain**: The job description focuses on supply chain operations, which is not explicitly mentioned in the resume.
# - **Vendor Management**: The job description requires communication with vendors, which is not a focus in the resume.
# - **Production Planning**: The job description mentions production planning, which is not addressed in the resume.
# - **Fashion Business Management**: The job description specifies a preference for candidates in this field, which is not relevant to the resume.
# - **ERP Systems**: The job description mentions maintaining records for supply chain ERP data, which is not covered in the resume.
#
# ### 3. Important Technical Skills
# - **Microsoft Excel**: The job description requires proficiency in Excel, which is a basic skill mentioned in the resume.
# - **Data Entry and Maintenance**: Important for the role, though not explicitly highlighted in the resume.
# - **Analytical Skills**: The resume showcases strong analytical skills through various projects and experiences, which could be beneficial for improving supply chain processes.
# - **Communication Tools**: While the resume lists various analytics tools, it does not mention specific tools for communication or project management, which may be relevant for the internship role.
# - **Process Improvement**: The resume indicates experience in improving processes, which aligns with the job's requirement to identify areas for efficiency in the supply chain.
#
# Overall, while there are some overlapping skills and attributes, the resume does not align closely with the specific requirements of the Production & Supply Planning Intern position, particularly in the context of supply chain and fashion business management.
#
#
# ================================================================================
# JD: Production & Supply Planning Intern
# Analysis Type: Skill Gap Analysis
# --------------------------------------------------------------------------------
# ### Skill Gap Report for Marcela Lozano
#
# #### 1. Missing Skills
# Based on the job description for the Production & Supply Planning Intern position, the following skills are identified as missing or underrepresented in Marcela's resume:
#
# - **Fashion Business Management Knowledge**: The job specifically requires a background in Fashion Business Management or a related field, which is not present in Marcela's educational background.
# - **Vendor Communication**: The role emphasizes communication with vendors regarding order status and delays, which is not explicitly highlighted in Marcela's experience.
# - **Supply Chain Operations**: While Marcela has experience in analytics and strategy, there is no direct mention of supply chain operations or logistics management.
# - **Basic Excel Skills**: Although Marcela lists advanced Excel skills, the job description emphasizes "basic Excel skills," which may imply a need for proficiency in fundamental functions rather than advanced analytics.
# - **Data Entry and ERP Systems**: The job requires maintaining records for supply chain ERP data, which is not mentioned in Marcela's experience.
#
# #### 2. Transferable Skills
# Marcela possesses several transferable skills that could be beneficial for the Production & Supply Planning Intern role:
#
# - **Analytical Skills**: Her background in business analytics and experience with data analysis can help in understanding supply chain metrics and improving processes.
# - **Communication Skills**: Experience in client management and presenting analytical findings indicates strong communication abilities, which are essential for vendor interactions.
# - **Problem-Solving**: Her experience in developing strategies and conducting analyses demonstrates a problem-solving mindset, which aligns with the job's requirements.
# - **Organizational Skills**: Managing multiple projects and engagements in her previous roles suggests strong organizational capabilities.
# - **Attention to Detail**: The precision required in her analytics work indicates a strong attention to detail, which is crucial for tracking purchase orders and maintaining records.
#
# #### 3. Recommendations
# To enhance her fit for the Production & Supply Planning Intern position, Marcela should consider the following recommendations:
#
# - **Gain Relevant Experience**: Seek internships or projects related to supply chain management or fashion business to build relevant experience and knowledge in the field.
# - **Develop Supply Chain Knowledge**: Consider taking online courses or certifications related to supply chain management, logistics, or fashion business to fill the knowledge gap.
# - **Highlight Communication Skills**: Emphasize any experience related to vendor communication or collaboration with external partners in her resume or cover letter.
# - **Familiarize with ERP Systems**: Learn about common ERP systems used in supply chain management to demonstrate readiness for data entry and record maintenance tasks.
# - **Tailor Resume for the Role**: Adjust her resume to highlight transferable skills and relevant experiences that align more closely with the job description, focusing on organizational and communication skills.
#
# By addressing these gaps and recommendations, Marcela can improve her candidacy for the Production & Supply Planning Intern position and better align her skills with the job requirements.
#
#
# ================================================================================
# JD: Associate Product Manager
# Analysis Type: Fit Summary
# --------------------------------------------------------------------------------
# ### 1. Overall Fit
# Marcela Lozano appears to be a strong candidate for the Associate Product Manager role at AXS. Her educational background in Business Analytics and Economics, combined with her technical skills in data analysis and product management experience, align well with the requirements of the position. Although she does not have direct experience in a formal Product Management role, her experience in strategy and analytics consulting, as well as her work with client management and research, suggests she possesses relevant skills and knowledge that can be effectively transferred to this role.
#
# ### 2. Strengths
# - **Educational Background**: Marcela is currently pursuing a Master's in Business Analytics with a perfect GPA, which demonstrates her strong analytical skills and commitment to her field. Her undergraduate degree in Economics, where she graduated as Valedictorian, further emphasizes her strong academic foundation.
#
# - **Technical Skills**: She has a robust set of technical skills, including proficiency in Python, SQL, Tableau, and various data analysis tools. This technical expertise will be beneficial in analyzing product landscape and customer feedback, as well as in preparing product documentation.
#
# - **Professional Experience**: Her role as a Strategy & Analytics Consultant at AutoDive involved developing commercialization strategies and conducting customer segmentation analysis, which is directly relevant to understanding business opportunities and customer needs. Additionally, her experience managing multiple strategy and investment research engagements at Coleman Research demonstrates her ability to juggle competing priorities.
#
# - **Project Experience**: Marcela has worked on several relevant projects, including sentiment analysis and customer segmentation, which showcase her ability to conduct research and analyze data to inform business decisions.
#
# - **Communication Skills**: Her experience in client management and delivering insights to Fortune 100 companies indicates strong verbal and written communication skills, which are essential for the role.
#
# ### 3. Weaknesses
# - **Lack of Direct Product Management Experience**: While Marcela has relevant experience in analytics and consulting, she does not have direct experience in a formal Product Management role, which may be a concern for a position that requires familiarity with the product marketing and launch process.
#
# - **Limited Experience with Development Tools**: The job description mentions familiarity with tools like Jira and Trello, which are not listed in her resume. This could indicate a gap in her experience with standard product management tools, although her technical background may allow her to quickly adapt.
#
# - **Experience Level**: The job requires 1-2 years of experience in a Product Management role, and while Marcela has relevant experience, it may not fully meet this specific requirement, potentially making her less competitive against candidates with direct product management backgrounds.
#
# ### Conclusion
# Overall, Marcela Lozano is a strong candidate for the Associate Product Manager role at AXS, with a solid educational background, relevant technical skills, and experience in analytics and consulting. However, her lack of direct product management experience and familiarity with specific development tools may present challenges. If she can effectively demonstrate her ability to adapt and leverage her analytical skills in a product management context, she could be a valuable addition to the team.
#
#
# ================================================================================
# JD: Associate Product Manager
# Analysis Type: Keyword Alignment
# --------------------------------------------------------------------------------
# ### 1. Matching Keywords
# - **Research**: Both the resume and job description emphasize the importance of conducting research.
# - **Customer Feedback**: The resume mentions customer segmentation analysis, which aligns with gathering customer feedback.
# - **Collaboration**: The resume highlights collaboration with internal teams, similar to the job description's requirement for working closely with various departments.
# - **Multiple Projects**: The resume indicates experience managing multiple engagements, which matches the job's requirement to juggle multiple projects.
# - **Communication Skills**: Both documents emphasize the need for strong verbal and written communication skills.
# - **Product Knowledge**: The resume's experience in strategy and analytics supports the need for product knowledge in the job description.
# - **Data Analysis**: The resume showcases skills in data analysis, which is relevant to analyzing the product landscape in the job description.
#
# ### 2. Missing Keywords
# - **Product Management**: The resume does not explicitly mention experience in a product management role, which is a key requirement in the job description.
# - **Product Roadmap**: There is no mention of experience in prioritizing features for a product roadmap.
# - **Sales and Marketing Support**: While the resume mentions collaboration with internal teams, it lacks specific references to supporting sales and marketing efforts.
# - **Technical Expertise**: The job description emphasizes the need for technical expertise in product management, which is not explicitly highlighted in the resume.
# - **Development Tools**: The resume does not mention familiarity with tools like Jira or Trello, which are specified in the job description.
# - **Mobile Apps**: There is no mention of experience or passion for mobile apps, which is a preference in the job description.
#
# ### 3. Important Technical Skills
# - **Data Analysis Tools**: Skills in SQL, Python, Tableau, and Excel are crucial for analyzing product landscape and customer feedback.
# - **ETL Pipelines**: Experience in building ETL pipelines can be beneficial for managing data related to product performance.
# - **NLP and Machine Learning**: Skills in NLP and machine learning can be useful for analyzing customer sentiment and trends.
# - **Data Visualization**: Proficiency in data visualization tools like Tableau and Power BI is important for presenting findings effectively.
# - **Project Management Tools**: Familiarity with project management tools (e.g., Jira, Trello) is important for managing multiple projects, as mentioned in the job description.
# - **Communication Tools**: Strong presentation and communication skills are essential for supporting internal and external groups, which is a key aspect of the role.
#
#
# ================================================================================
# JD: Associate Product Manager
# Analysis Type: Skill Gap Analysis
# --------------------------------------------------------------------------------
# ### Skill Gap Report for Marcela Lozano
#
# #### 1. Missing Skills
# Based on the job description for the Associate Product Manager role at AXS, the following skills and experiences are identified as missing or underrepresented in Marcela's resume:
#
# - **Product Management Experience**: The job requires 1-2 years of experience in a Product Management role, which is not explicitly stated in Marcela's resume.
# - **Knowledge of Product Marketing/Launch Process**: While Marcela has experience in strategy and analytics, there is no specific mention of product marketing or launch processes.
# - **Familiarity with Development Tools**: The job description mentions familiarity with tools like Jira and Trello, which are not listed in Marcela's technical skills.
# - **Customer Feedback and Research**: The role emphasizes gathering customer feedback and conducting research to inform product decisions, which is not highlighted in her experience.
# - **Experience with Mobile Apps**: The job description mentions a passion for mobile apps (Android), which is not addressed in Marcela's resume.
#
# #### 2. Transferable Skills
# Despite the missing skills, Marcela possesses several transferable skills that could be beneficial for the Associate Product Manager role:
#
# - **Analytical Skills**: Her experience in data analysis, customer segmentation, and sentiment analysis demonstrates strong analytical capabilities that can be applied to understanding customer needs and product landscape.
# - **Communication Skills**: Marcela has experience in delivering insights and collaborating with various teams, which aligns with the requirement for effective verbal and written communication.
# - **Project Management**: While not in a formal product management capacity, her experience managing multiple strategy and investment research engagements indicates strong organizational skills and the ability to juggle competing priorities.
# - **Technical Expertise**: Her technical skills in data visualization and analytics tools can support product documentation and provide technical knowledge to sales and marketing teams.
# - **Research and Insight Generation**: Her background in conducting research and generating business insights can be leveraged to inform product development and strategy.
#
# #### 3. Recommendations
# To bridge the skill gaps and enhance her fit for the Associate Product Manager role, Marcela should consider the following recommendations:
#
# - **Gain Product Management Experience**: Seek opportunities to work on product management projects, even in a volunteer or internship capacity, to gain relevant experience and demonstrate her understanding of the product management discipline.
# - **Familiarize with Product Marketing**: Engage in courses or workshops focused on product marketing and the product launch process to build knowledge in this area.
# - **Learn Development Tools**: Familiarize herself with project management tools such as Jira and Trello, possibly through online tutorials or by using them in personal projects.
# - **Engage in Customer Research**: Participate in projects that involve gathering customer feedback and conducting market research to strengthen her ability to understand customer needs.
# - **Explore Mobile App Development**: Consider taking courses or working on projects related to mobile app development to align with the job's emphasis on technology and mobile applications.
#
# By addressing these recommendations, Marcela can enhance her qualifications for the Associate Product Manager role and better position herself for success in this career path.

# %% [markdown]
# ### Evaluation Analysis
#
# | Position | Analysis Type | Retrieval Relevance | Skill Identification Accuracy | Actionability | Faithfulness | Notes |
# |---|---|---|---|---|---|---|
# | Data Analyst Lead | Fit Summary | Yes | Correct: analytics background, SQL, Python, Tableau, Power BI and communication. Partial: demand forecasting and pricing optimization slightly overstated. Incorrect: A/B Testing is listed as hands on experience but resume specifies only a conceptual understanding. | 4 | Partial | Strong overall fit assessment, but slightly overstated experience level. |
# | Data Analyst Lead | Keyword Alignment | Yes | Correct: Tableau, Power BI, forecasting, customer segmentation, SQL, ML, communication. Partial: pricing strategy and business partnering were inferred from transferable experience. Incorrect: none major. | 4 | Faithful | Strong keyword extraction and alignment quality. Actionable summary is provided indicating a lack of specific experience like ticketing strategy. |
# | Data Analyst Lead | Skill Gap Analysis | Yes | Correct: pricing elasticity gap, ticketing analytics gap, experimentation platforms, advanced SQL/BI skills. Partial: business partnering and ML specialization partially inferred. Incorrect: none major. | 5 | Faithful | Most actionable and detailed output. Correctly identified that A/B testing is only known conceptually. |
# | Production & Supply Planning Intern | Fit Summary | Partial | Correct: analytical skills, data management, organization, project management. Partial: supply chain process improvement potential inferred from analytics background. Incorrect: none major. | 4 | Partial | Transferable skills identified correctly, but domain alignment was weaker. |
# | Production & Supply Planning Intern | Keyword Alignment | Yes | Correct: communication, organization, attention to detail, data management. Partial: vendor communication partially inferred from client management. Incorrect: none major. | 4 | Faithful | Accurate identification of missing supply chain terminology. |
# | Production & Supply Planning Intern | Skill Gap Analysis | Yes | Correct: ERP systems, vendor communication, fashion business knowledge, supply chain gaps. Partial: Excel gap somewhat overstated because Excel already exists in resume. Incorrect: none major. | 5 | Faithful | Recommendations were realistic and actionable. |
# | Associate Product Manager | Fit Summary | Yes | Correct: cross-functional collaboration, analytics, communication, project management. Partial: product strategy and customer research partially inferred from consulting experience. Incorrect: none major. | 4 | Faithful | Strong transferable skills identified for PM role. |
# | Associate Product Manager | Keyword Alignment | Yes | Correct: research, collaboration, communication, data analysis, multiple projects. Partial: product knowledge partially inferred from strategy work. Incorrect: none major. | 4 | Faithful | Good distinction between matched and missing PM terminology. |
# | Associate Product Manager | Skill Gap Analysis | Yes | Correct: product roadmap, Jira/Trello, product marketing, customer feedback gaps. Partial: PM methodology gaps inferred indirectly. Incorrect: none major. | 5 | Faithful | Clear recommendations for transitioning into PM roles. |
#
# ### Which analysis type worked best?
#
# The Skill Gap Analysis performed the best overall since it produced the most specific, realistic, and actionable feedback. When compared to the Fit Summary and Keyword Alignment outputs, the Skill Gap Analysis was better at identifying what was missing from the resume and explaining how the candidate could improve their alignment with each role.
#
# For example, the Skill Gap Analysis correctly identified gaps like pricing elasticity, ticketing analytics, ERP systems, vendor communication, fashion business knowledge, product roadmap experience, Jira/Trello, product marketing, and customer feedback experience. These outputs were also the most useful and actionable because they gave clear recommendations that could actually be applied directly to resume revisions or interview preparation.
#
# The Fit Summary was useful for a quick overview, but it often times overstated experience. The Keyword Alignment was strong for identifying matched and missing terms but it was still less detailed than the Skill Gap Analysis.
#
# ---
#
# ### Which job descriptions produced the best and worst results? Why?
#
# The Data Analyst Lead and Associate Product Manager job descriptions produced the strongest results. These roles aligned the best with the candidate resume because they emphasized analytics, communication, SQL, Python, Tableau, Power BI, project work, research, and cross-functional collaboration. Since these skills were clearly represented in the resume, the system was able to produce more relevant and faithful outputs.
#
# The Production & Supply Planning Intern job description produced the weakest results. Even though the output was useful, the role was more supply chain specific while the resume was stronger in analytics, client management, and business strategy. Due to the weaker domain alignment, the model relied more on transferable skills. One example is that it connected client management to vendor communication and analytics work to supply chain process improvement. This connection is more indirect and a result of the model inferring skills.
#
# Overall, job descriptions with strong overlap in analytics and business skills produced better results, while job descriptions requiring specialized domain experience produced more partial or inferred findings.
#
#
# ---
#
# ### Where did the system hallucinate or produce inaccurate results?
#
# The system did not have any major hallucinations, but it did sometimes overstate or infer experience beyond what was directly supported by the resume. The main issue was that the model sometimes treated transferable or conceptual experience as direct experience.
#
# For example, in the Data Analyst Lead Fit Summary, the model listed A/B testing as hands-on experience, but the resume only supports a conceptual understanding of A/B testing. The model also slightly overstated demand forecasting, pricing optimization, and pricing strategy experience. These topics may be related to analytics coursework or transferable business experience, but they were not strongly supported as direct work experience.
#
# For the Production & Supply Planning Intern role, the system partially inferred supply chain process improvement and vendor communication from broader analytics and client management experience. These were reasonable connections, but they were not directly stated in the resume. The Excel gap was also somewhat overstated because Excel already appears in the resume.
#
# These issues show that the system was mostly faithful, but it sometimes needed stronger instructions to separate direct evidence from inferred transferable skills.
#
#
# ---
#
# ### What would you improve?
#
# I would improve the system by making the prompts more strict about evidence checking. Specifically, I would require the model to label each skill as either directly supported, partially supported, or not supported by the resume. This would reduce the chance of overstating experience.
#
# I would also improve the retrieval step by making sure the model pulls both the most relevant job description sections and the most relevant resume sections before generating the analysis. This would make the outputs more grounded and easier to evaluate.
#
# Another improvement would be to add a stronger hallucination check at the end of each output. The model could ideally review its own answer and flag any claims that are not directly supported by the resume or job description. This would be especially helpful for roles with weaker alignment like the Production & Supply Planning Intern position.

# %% [markdown]
# ---
#
# ## Next Steps
#
# 1. Build your Streamlit app (`streamlit_app.py`) using the pipeline from this notebook
# 2. Write your Technical Manager Memo (`memo.md`)
# 3. Complete your AI Usage Log (`ai_log.md`)
# 4. Verify GitHub repository structure and commit count
#
# ---
# *BSAN 6200 | Spring 2026 | Assignment 5 — Option B*
